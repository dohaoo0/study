# %%
n=3
list=[]
for i in range (n):
    a= input('nhap a')
    list.append(a)

    if '-' in list[i]:
        list[i]=int(list[i])
    elif list[i]>='0' and list[i]<='9':
        liat[i]=int(list[i])
print(list)
# Out:
# ['99', -99, '999']

# %%
n=3
list=[]
for i in range(n):
    x=int(input())
    list.append(x)
print(list)
# Out:
# [34, 12, 4]

# %%
#nhập vào một list, kiểm tra phần tử, nếu là chữ thì in theo kiểu string, còn nếu là số thì in theo kiểu int
n=3
l=[]
for i in range(3):
    x=input('nhap phan tu: ')
    l.append(x)
    if '-' in l[i]:
        l[i]=int(l[i])
    elif '9' in l[i]:
        l[i]=int(l[i])
    elif l[i]>='0' and l[i]<='9':
        l[i]= int(l[i])

print(l)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 10
#       8     l[i]=int(l[i])
#       9 elif '9' in l[i]:
# ---> 10     l[i]=int(l[i])
#      11 elif l[i]>='0' and l[i]<='9':
#      12     l[i]= int(l[i])
#
# ValueError: invalid literal for int() with base 10: 'mi9'

# %%
#đưa từng phần tử của list về dạng string, rồi lấy từng phần tử của string kiểm tra 
# nếu phần tử đầu của string khác từ 0 đến 9 thì nó sẽ in theo kiểu string
# nếu là số thì kiểm tra phần tử tiếp theo, tương tự cho đến hết chuỗi, là số tự nhiên or thập phân thì in kiểu số, là chữ thi

# %%
def ktra(x):
    x=str(x)
    l=len(x)
    b=0
    if x[0]=='-':
        a=1
    else: 
        a=0
    for i in range (a,l+1):
        if x[i] <= '0' or x[i]>= '9':
            if x[i]=='.' and i>=a+1 and b==0:
                b=1
            else:
                return 0
    return x
a=['99', 'mi9', '999','90','9.344']
for i in a:
    if ktra(i):
        print(a[i])

# %%
if False and False:
    print('vi du toan tu and')
elif True and False:
    print('vi du toan tu or')
elif not True:
    print('vi du toan tu not')
else: 
    print('truong hop con lai')
# Out:
# truong hop con lai

# %%
print('hảo','\t', 'vy','\t','trang')
# Out:
# hảo 	 vy 	 trang

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 8
#       5     mean = sum_list / len(number_list)
#       6     print(mean)
# ----> 8 calculate_variance(2)
#
# Cell In[4], line 3, in calculate_variance(number_list)
#       1 def calculate_variance(number_list):
#       2     sum_list = 0
# ----> 3     for number in number_list:
#       4         sum_list = sum_list + number
#       5     mean = sum_list / len(number_list)
#
# TypeError: 'int' object is not iterable

# %%
if __name__ == '__main__':
    n = int(input())
    arr = map(int, input().split())
    m= arr[0]
    for i in range(n):
        if m < arr[i]:
            m=arr[i]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       2 n = int(input())
#       3 arr = map(int, input().split())
# ----> 4 m= arr[0]
#       5 for i in range(n):
#       6     if m < arr[i]:
#
# TypeError: 'map' object is not subscriptable
